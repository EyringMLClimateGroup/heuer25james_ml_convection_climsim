# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
import seaborn as sns
import cartopy.crs as ccrs

# %%
# # todo: change for precip/tas
# obs = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_baseline_1979_20250715_070122UTC/esmvaltool_output/recipe_basics_maps_20250715_070310/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_baseline_1979_tas_ICON_Amon_top_right.nc')
# tiedtke_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_baseline_1979_20250715_070122UTC/esmvaltool_output/recipe_basics_maps_20250715_070310/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_baseline_1979_tas_ICON_Amon_top_left.nc')
# # ml_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.03_20250715_133437UTC/esmvaltool_output/recipe_basics_maps_20250715_133710/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.03_tas_ICON_Amon_top_left.nc')
# # ml_tl = xr.open_dataset('/scratch/b/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.05_20250726_215208UTC/esmvaltool_output/recipe_basics_maps_20250726_215404/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.05_tas_ICON_Amon_top_left.nc')
# ml_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.2_20250802_083015UTC/esmvaltool_output/recipe_basics_maps_20250802_084149/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.2_tas_ICON_Amon_top_left.nc')
# # mix_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.03_20250706_141931UTC/esmvaltool_output/recipe_basics_maps_20250706_142122/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.03_tas_ICON_Amon_top_left.nc')
# mix_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.2_extra2d5fix_20250805_065411UTC/esmvaltool_output/recipe_basics_maps_20250805_074516/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.2_extra2d5fix_tas_ICON_Amon_top_left.nc')
# tiedtke_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_baseline_1979_20250715_070122UTC/esmvaltool_output/recipe_basics_maps_20250715_070310/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_baseline_1979_tas_ICON_Amon_bottom.nc')
# # ml_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.03_20250715_133437UTC/esmvaltool_output/recipe_basics_maps_20250715_133710/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.03_tas_ICON_Amon_bottom.nc')
# # ml_b = xr.open_dataset('/scratch/b/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.05_20250726_215208UTC/esmvaltool_output/recipe_basics_maps_20250726_215404/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.05_tas_ICON_Amon_bottom.nc')
# ml_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.2_20250802_083015UTC/esmvaltool_output/recipe_basics_maps_20250802_084149/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.2_tas_ICON_Amon_bottom.nc')
# # mix_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.03_20250706_141931UTC/esmvaltool_output/recipe_basics_maps_20250706_142122/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.03_tas_ICON_Amon_bottom.nc')
# mix_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.2_extra2d5fix_20250805_065411UTC/esmvaltool_output/recipe_basics_maps_20250805_074516/work/maps_tas/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.2_extra2d5fix_tas_ICON_Amon_bottom.nc')

obs = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_baseline_1979_20250715_070122UTC/esmvaltool_output/recipe_basics_maps_20250715_070310/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_baseline_1979_pr_ICON_Amon_top_left.nc')
tiedtke_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_baseline_1979_20250715_070122UTC/esmvaltool_output/recipe_basics_maps_20250715_070310/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_baseline_1979_pr_ICON_Amon_top_left.nc')
# ml_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.03_20250715_133437UTC/esmvaltool_output/recipe_basics_maps_20250715_133710/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.03_pr_ICON_Amon_top_left.nc')
# ml_tl = xr.open_dataset('/scratch/b/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.05_20250726_215208UTC/esmvaltool_output/recipe_basics_maps_20250726_215404/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.05_pr_ICON_Amon_top_left.nc')
ml_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.2_20250802_083015UTC/esmvaltool_output/recipe_basics_maps_20250802_084149/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.2_pr_ICON_Amon_top_left.nc')
# mix_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.03_20250706_141931UTC/esmvaltool_output/recipe_basics_maps_20250706_142122/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_19/79_noise0.03_pr_ICON_Amon_top_left.nc')
mix_tl = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.2_extra2d5fix_20250805_065411UTC/esmvaltool_output/recipe_basics_maps_20250805_074516/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.2_extra2d5fix_pr_ICON_Amon_top_left.nc')
tiedtke_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_baseline_1979_20250715_070122UTC/esmvaltool_output/recipe_basics_maps_20250715_070310/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_baseline_1979_pr_ICON_Amon_bottom.nc')
# ml_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.03_20250715_133437UTC/esmvaltool_output/recipe_basics_maps_20250715_133710/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.03_pr_ICON_Amon_bottom.nc')
# ml_b = xr.open_dataset('/scratch/b/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.05_20250726_215208UTC/esmvaltool_output/recipe_basics_maps_20250726_215404/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.05_pr_ICON_Amon_bottom.nc')
ml_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.2_20250802_083015UTC/esmvaltool_output/recipe_basics_maps_20250802_084149/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_fullml_1979_noise0.2_pr_ICON_Amon_bottom.nc')
# mix_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.03_20250706_141931UTC/esmvaltool_output/recipe_basics_maps_20250706_142122/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_/1979_noise0.03_pr_ICON_Amon_bottom.nc')
mix_b = xr.open_dataset('/work/bd1179/b309215/MyIconEval/WorkEvalBackup/heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.2_extra2d5fix_20250805_065411UTC/esmvaltool_output/recipe_basics_maps_20250805_074516/work/maps_pr/plot/map_heuer_atm_amip_R2B4_vlvl60_nonconservative_nn0.54M_ncorr42_10p0_60p1_pinnweight0.1_1979_noise0.2_extra2d5fix_pr_ICON_Amon_bottom.nc')

# %%
# todo: change for precip/tas
var = 'pr'
biasvar = 'bias_pr'
# var = 'tas'
# biasvar = 'bias_tas'

# %%
# ax = plt.subplot(projection=ccrs.PlateCarree())
fig, ax = plt.subplots(subplot_kw=dict(projection=ccrs.PlateCarree()), constrained_layout=True)
p = obs[var].plot.pcolormesh(x="lon", y="lat", ax=ax, add_colorbar=False)
fig.colorbar(p, orientation='horizontal')
ax.coastlines()
ax.set_title('Tiedtke')
ax.gridlines(draw_labels=True);

# %%
# ax = plt.subplot(projection=ccrs.PlateCarree())
fig, ax = plt.subplots(subplot_kw=dict(projection=ccrs.PlateCarree()), constrained_layout=True)
p = tiedtke_tl[var].plot.pcolormesh(x="lon", y="lat", ax=ax, add_colorbar=False)
fig.colorbar(p, orientation='horizontal')
ax.coastlines()
ax.set_title('Tiedtke')
ax.gridlines(draw_labels=True);

# %%
# ax = plt.subplot(projection=ccrs.PlateCarree())
fig, ax = plt.subplots(subplot_kw=dict(projection=ccrs.PlateCarree()), constrained_layout=True)
p = tiedtke_tl[var].plot.pcolormesh(x="lon", y="lat", ax=ax, add_colorbar=False)
fig.colorbar(p, orientation='horizontal')
ax.coastlines()
ax.set_title('Tiedtke')
ax.gridlines(draw_labels=True);

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection=ccrs.PlateCarree()), constrained_layout=True)
p = ml_tl[var].plot.pcolormesh(x="lon", y="lat", ax=ax, add_colorbar=False)
fig.colorbar(p, orientation='horizontal')
ax.coastlines()
ax.set_title('Pure ML')
ax.gridlines(draw_labels=True);

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection=ccrs.PlateCarree()), constrained_layout=True)
p = mix_tl[var].plot.pcolormesh(x="lon", y="lat", ax=ax, add_colorbar=False)
fig.colorbar(p, orientation='horizontal')
ax.coastlines()
ax.set_title('Mixed:10-60')
ax.gridlines(draw_labels=True);

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection=ccrs.PlateCarree()), constrained_layout=True)
p = mix_b[biasvar].plot.pcolormesh(x="lon", y="lat", ax=ax, add_colorbar=False)
fig.colorbar(p, orientation='horizontal')
ax.coastlines()
ax.set_title('Mixed:10-60')
ax.gridlines(draw_labels=True);

# %%
left_ds = [tiedtke_tl, ml_tl, mix_tl]
right_ds = [tiedtke_b, ml_b, mix_b]

left_col_min = min([ds[var].values.min() for ds in left_ds] + [obs[var].min()])
left_col_max = max([ds[var].values.max() for ds in left_ds] + [obs[var].max()])
right_col_min = min([ds[biasvar].values.min() for ds in right_ds])
right_col_max = max([ds[biasvar].values.max() for ds in right_ds])

left_col_min, left_col_max, right_col_min, right_col_max
# Out:
# (0.001289976, 13.7185755, -10.211021, 8.654585)

# %%
weights = np.cos(tiedtke_b.lat*np.pi/180).values
weights_2d = np.repeat(weights[:, np.newaxis], 180, axis=1)
weights_2d = weights_2d / weights_2d.sum()

# meanbias_tiedtke = tiedtke_b[biasvar].mean().item()
meanbias_tiedtke = np.sum(tiedtke_b[biasvar]*weights_2d).item()
# meanbias_ml = ml_b[biasvar].mean().item()
meanbias_ml = np.sum(ml_b[biasvar]*weights_2d).item()
# meanbias_mix = mix_b[biasvar].mean().item()
meanbias_mix = np.sum(mix_b[biasvar]*weights_2d).item()
biases = (meanbias_tiedtke, meanbias_ml, meanbias_mix)
biases
# tas
# (0.5565001368522644, 1.7095695734024048, -0.27129611372947693)
# (0.5044059481754201, 1.0329420450888445, -0.25529526470748876)
# precip
# (-0.15054461359977722, -0.2725384533405304, 0.14143754541873932)
# (-0.21106513236255742, -0.3432195067769092, 0.14241519415300508)
# Out:
# (-0.21106513236255742, -0.3432195067769092, 0.14241519415300508)

# %%
# np.sqrt((tiedtke_b[biasvar]**2).mean().item()), np.sqrt((ml_b[biasvar]**2).mean().item()), np.sqrt((mix_b[biasvar]**2).mean().item())
np.sqrt((tiedtke_b[biasvar]**2*weights_2d).sum().item()), np.sqrt((ml_b[biasvar]**2*weights_2d).sum().item()), np.sqrt((mix_b[biasvar]**2*weights_2d).sum().item())
# tas
# (1.6019089486896463, 2.8883933860961943, 1.6940287286783677)
# precip
# (1.1206465836173463, 1.1387951949328716, 1.2290846533273698)
# (1.3528710879490555, 1.363299247858513, 1.4812267984946186)
# Out:
# (1.3528710879490555, 1.363299247858513, 1.4812267984946186)

# %%
import string
from setup_mpl_tex import setup_mpl_tex
from matplotlib.gridspec import GridSpec

setup_mpl_tex()

# fig, ax = plt.subplots(4, 2, subplot_kw=dict(projection=ccrs.PlateCarree()), constrained_layout=True, figsize=(6.4,7))
# obs_ax = ax[0,0]
# ax[0,1].axis('off')
# ax = ax[1:,:]

fig = plt.figure(layout="constrained", figsize=(6.4,7))
gs = GridSpec(4, 4, figure=fig)
ax = []
obs_ax = fig.add_subplot(gs[0,1:3], projection=ccrs.PlateCarree())
for i in range(1,4):
    for j in range(2):
        ax.append(fig.add_subplot(gs[i,j*2:j*2+2], projection=ccrs.PlateCarree()))
ax = np.array(ax).reshape(3,2)

# todo: change for precip/tas
cmap = plt.get_cmap('Blues')
# cmap = plt.get_cmap('plasma')

left_p = []
p = obs[var].plot.pcolormesh(x="lon", y="lat", ax=obs_ax, add_colorbar=False, vmin=left_col_min, vmax=left_col_max, cmap=cmap, zorder=-1)
left_p.append(p)
for i,ds in enumerate(left_ds):
    p = ds[var].plot.pcolormesh(x="lon", y="lat", ax=ax[i,0], add_colorbar=False, vmin=left_col_min, vmax=left_col_max, cmap=cmap, zorder=-1)
    # p = ds[var].plot.pcolormesh(x="lon", y="lat", ax=ax[i*2], add_colorbar=False, vmin=left_col_min, vmax=left_col_max, cmap=cmap, zorder=-1)
    left_p.append(p)

right_p = []
for i,ds in enumerate(right_ds):
    p = ds[biasvar].plot.pcolormesh(x="lon", y="lat", ax=ax[i,1], add_colorbar=False, vmin=right_col_min, vmax=right_col_max, cmap='bwr', zorder=-1)
    # p = ds[biasvar].plot.pcolormesh(x="lon", y="lat", ax=ax[2*i+1,1], add_colorbar=False, vmin=right_col_min, vmax=right_col_max, cmap='bwr', zorder=-1)
    right_p.append(p)

# todo: change for precip/tas
fig.colorbar(left_p[0], ax=ax[:,0], orientation='horizontal', label='Precipitation (mm d$^{-1}$)', shrink=0.9)
fig.colorbar(right_p[0], ax=ax[:,1], orientation='horizontal', label='Precipitation Bias (mm d$^{-1}$)', shrink=0.9)
# fig.colorbar(left_p[0], ax=ax[:,0], orientation='horizontal', label='Temperature (K)', shrink=0.9)
# fig.colorbar(right_p[0], ax=ax[:,1], orientation='horizontal', label='Temperature Bias (K)', shrink=0.9)

labels = string.ascii_lowercase[:ax.size+1]
labelidx = 0
for i,axx in enumerate([obs_ax]+list(ax.ravel())):
    axx.set_rasterization_zorder(0)
    axx.coastlines()
    axx.gridlines()
    axx.set_title(None)
    # axx.text(x=-0.02, y=1, s=labels[labelidx]+')', rotation=0, ha='right', va='center', fontsize=12, transform=axx.transAxes, zorder=1);
    axx.set_title(labels[labelidx]+')', loc='left', zorder=1);
    labelidx += 1
    # axx.set_title(label+')', x=-0.05, loc='left')

# ax[0,0].set_ylabel('Reference')
# ax[1,0].set_ylabel('Tiedtke')
# ax[2,0].set_ylabel('Pure ML')
# ax[3,0].set_ylabel('Mixed:10-60')
# todo: change for precip/tas
obs_label = 'GPCP'
# obs_label = 'ERA5'
# obs_ax.text(x=-0.02, y=0.5, s=obs_label, rotation=90, ha='right', va='center', fontsize=12, transform=obs_ax.transAxes, zorder=1);
obs_ax.set_title(obs_label, zorder=1);
for i,(label,b) in enumerate(zip(['Tiedtke', 'Pure ML', 'Mixed:10-60'], biases)):
    # ax[i,0].text(x=-0.02, y=0.5, s=label, rotation=90, ha='right', va='center', fontsize=12, transform=ax[i,0].transAxes, zorder=1);
    # ax[i,1].text(x=-0.02, y=0.5, s=label, rotation=90, ha='right', va='center', fontsize=12, transform=ax[i,1].transAxes, zorder=1);
    ax[i,0].set_title(label, fontsize=12);
    ax[i,1].set_title(label, fontsize=12);
    # todo: change for precip/tas
    ax[i,1].set_title(str(round(b,2))+"\,mm/d", loc='right', size='medium')
    # ax[i,1].set_title(str(round(b,2))+"\,K", loc='right', size='medium')

# todo: change for precip/tas
fig.savefig('Figures/20y_precip_vs_gpcp.pdf', dpi=300, bbox_inches='tight')
# fig.savefig('Figures/20y_tas_vs_era5.pdf', dpi=300, bbox_inches='tight')
